# %%
from main import Model  

model = Model()

model.load_model()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 5
#       1 from main import Model
#       3 model = Model()
# ----> 5 model.load_model()
#
# File ~/code/BlueSpirit1993/hdb_resale_chat_bot/models/hdb/main.py:187, in Model.load_model(self)
#     186 def load_model(self):
# --> 187     with open("lightgbm_pipeline.pkl", "rb") as f:
#     188         self.pipeline = pickle.load(f)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'lightgbm_pipeline.pkl'
