# %%
from main import Model  

model = Model()

model.load_model()

# %%
user_query = {
    "block": "101",
    "street_name": "TAMPINES STREET 11",
    "town": "TAMPINES",
    "flat_type": "4 ROOM",
    "storey_range": "Mid",
    "floor_area_sqm": 93,
    "remaining_lease_year": 89,
    "month_year": "03-2024"
}

# %%
prediction = model.get_preds(user_query)
print(prediction)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 prediction = model.get_preds(user_query)
#       2 print(prediction)
#
# File ~/code/BlueSpirit1993/hdb_resale_chat_bot/models/hdb/main.py:193, in Model.get_preds(self, user_query)
#     192 def get_preds(self, user_query):
# --> 193     x = self.preprocess(user_query)
#     194     return self.pipeline.predict(x.to_frame().T)
#
# File ~/code/BlueSpirit1993/hdb_resale_chat_bot/models/hdb/main.py:171, in Model.preprocess(self, user_query)
#     168 block = user_query["block"]
#     169 street_name = user_query["street_name"]
# --> 171 mrt_info = self.get_nearest_mrt_info(block, street_name)
#     172 school_info = self.get_nearest_school_info(block, street_name)
#     173 preprocessed_user_query["line"] = mrt_info["line"]
#
# File ~/code/BlueSpirit1993/hdb_resale_chat_bot/models/hdb/main.py:113, in Model.get_nearest_mrt_info(self, block, street_name)
#     112 def get_nearest_mrt_info(self, block, street_name):
# --> 113     lat, lon = self.get_coordinates(block, street_name)
#     114     mrt_df = self.mrt
#     116     addr_coords = np.radians(np.array([[lat, lon]]))
#
# File ~/code/BlueSpirit1993/hdb_resale_chat_bot/models/hdb/main.py:85, in Model.get_coordinates(self, block, street_name)
#      83 data = response.json()
#      84 result = data["results"][0]
# ---> 85 if not results:
#      86     raise ValueError(f"No coordinates found for address: {add}")
#      87 result = results[0]
#
# NameError: name 'results' is not defined
