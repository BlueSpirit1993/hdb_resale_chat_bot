# %%
from hdb_main import Model

model = Model()
model.load_model()

user_query = {
    "block": "309",
    "street_name": "ANG MO KIO AVE 1",
    "town": "ANG MO KIO",
    "flat_type": "4 ROOM",
    "storey_range": "Mid",
    "floor_area_sqm": 93,
    "remaining_lease_year": 89,
    "month_year": "03-2024"
}

prediction = model.get_preds(user_query)
prediction
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[1], line 17
#       4 model.load_model()
#       6 user_query = {
#       7     "block": "309",
#       8     "street_name": "ANG MO KIO AVE 1",
#    (...)
#      14     "month_year": "03-2024"
#      15 }
# ---> 17 prediction = model.get_preds(user_query)
#      18 prediction
#
# File ~/code/BlueSpirit1993/hdb_resale_chat_bot/models/hdb/hdb_main.py:173, in Model.get_preds(self, user_query)
#     172 def get_preds(self, user_query):
# --> 173     x = self.preprocess(user_query)
#     174     return self.pipeline.predict(x.to_frame().T)
#
# File ~/code/BlueSpirit1993/hdb_resale_chat_bot/models/hdb/hdb_main.py:155, in Model.preprocess(self, user_query)
#     153 preprocessed_user_query["nearest_mrt_name"] = mrt_info["nearest_mrt_name"]
#     154 preprocessed_user_query["nearest_sch_name"] = school_info["nearest_sch_name"]
# ...
